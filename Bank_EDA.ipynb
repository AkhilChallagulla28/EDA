# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("bank-additional.csv",sep=";")
df.head(10)
# Out:
#    age           job   marital            education  default  housing  \
# 0   30   blue-collar   married             basic.9y       no      yes
# 1   39      services    single          high.school       no       no
# 2   25      services   married          high.school       no      yes
# 3   38      services   married             basic.9y       no  unknown
# 4   47        admin.   married    university.degree       no      yes
# 5   32      services    single    university.degree       no       no
# 6   32        admin.    single    university.degree       no      yes
# 7   41  entrepreneur   married    university.degree  unknown      yes
# 8   31      services  divorced  professional.course       no       no
# 9   35   blue-collar   married             basic.9y  unknown       no
#
#       loan    contact month day_of_week  ...  campaign  pdays  previous  \
# 0       no   cellular   may         fri  ...         2    999         0
# ...

# %%
df.shape
# Out:
# (4119, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119 entries, 0 to 4118
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             4119 non-null   int64
#  1   job             4119 non-null   object
#  2   marital         4119 non-null   object
#  3   education       4119 non-null   object
#  4   default         4119 non-null   object
#  5   housing         4119 non-null   object
#  6   loan            4119 non-null   object
#  7   contact         4119 non-null   object
#  8   month           4119 non-null   object
#  9   day_of_week     4119 non-null   object
#  10  duration        4119 non-null   int64
#  11  campaign        4119 non-null   int64
#  12  pdays           4119 non-null   int64
#  13  previous        4119 non-null   int64
#  14  poutcome        4119 non-null   object
#  15  emp.var.rate    4119 non-null   float64
#  16  cons.price.idx  4119 non-null   float64
# ...

# %%
df.describe()
# Out:
#                age     duration     campaign        pdays     previous  \
# count  4119.000000  4119.000000  4119.000000  4119.000000  4119.000000
# mean     40.113620   256.788055     2.537266   960.422190     0.190337
# std      10.313362   254.703736     2.568159   191.922786     0.541788
# min      18.000000     0.000000     1.000000     0.000000     0.000000
# 25%      32.000000   103.000000     1.000000   999.000000     0.000000
# 50%      38.000000   181.000000     2.000000   999.000000     0.000000
# 75%      47.000000   317.000000     3.000000   999.000000     0.000000
# max      88.000000  3643.000000    35.000000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m  nr.employed
# count   4119.000000     4119.000000    4119.000000  4119.000000  4119.000000
# mean       0.084972       93.579704     -40.499102     3.621356  5166.481695
# std        1.563114        0.579349       4.594578     1.733591    73.667904
# ...

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
cat_col=df.select_dtypes(include='object')
cat_col
# Out:
#               job  marital          education default  housing     loan  \
# 0     blue-collar  married           basic.9y      no      yes       no
# 1        services   single        high.school      no       no       no
# 2        services  married        high.school      no      yes       no
# 3        services  married           basic.9y      no  unknown  unknown
# 4          admin.  married  university.degree      no      yes       no
# ...           ...      ...                ...     ...      ...      ...
# 4114       admin.  married           basic.6y      no      yes      yes
# 4115       admin.  married        high.school      no      yes       no
# 4116      student   single        high.school      no       no       no
# 4117       admin.  married        high.school      no       no       no
# 4118   management   single        high.school      no      yes       no
#
#         contact month day_of_week     poutcome   y
# 0      cellular   may         fri  nonexistent  no
# ...

# %%
num_col=df.select_dtypes(exclude='object').columns
num_col
# Out:
# Index(['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate',
#        'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed'],
#       dtype='object')

# %%
for i in cat_col:
    print(f"==> The column name is {i}")
    print(f"==> for this colum {i} the unique values are {df[i].unique()}")
    print(f"==> valuecount {df[i].value_counts()}")
    print(f"==> number of unique values are {df[i].nunique()}")
    print("------------------------------------------------------------------------------------")
# Out:
# ==> The column name is job
# ==> for this colum job the unique values are ['blue-collar' 'services' 'admin.' 'entrepreneur' 'self-employed'
#  'technician' 'management' 'student' 'retired' 'housemaid' 'unemployed'
#  'unknown']
# ==> valuecount job
# admin.           1012
# blue-collar       884
# technician        691
# services          393
# management        324
# retired           166
# self-employed     159
# entrepreneur      148
# unemployed        111
# housemaid         110
# student            82
# unknown            39
# Name: count, dtype: int64
# ==> number of unique values are 12
# ------------------------------------------------------------------------------------
# ==> The column name is marital
# ==> for this colum marital the unique values are ['married' 'single' 'divorced' 'unknown']
# ==> valuecount marital
# married     2509
# single      1153
# divorced     446
# unknown       11
# Name: count, dtype: int64
# ==> number of unique values are 4
# ...

# %%
df['job'].value_counts().plot(kind="bar")
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.countplot(x='job', data=df)
plt.show()

# %%
df['job'].value_counts().plot(kind='pie')
plt.show()

# %%
df['duration'].plot(kind='hist')
plt.show()

# %%
for i in range(len(num_col)):
    plt.figure(figsize=(15,5))
    plt.subplot(2,5,i+1)
    df[num_col[i]].plot(kind='hist')
    plt.title(f"{num_col[i]}")

# %%
for i in range(len(num_col)):
    plt.figure(figsize=(5,1))
    plt.subplot(2,5,i+1)
    sns.displot(df[num_col[i]])
    plt.title(f"{num_col[i]}")

# %%
for i,j in enumerate(num_col,1):
    plt.figure(figsize=(20,5))
    plt.subplot(4,3,i+1)
    sns.boxplot(df[j],orient='h')
    plt.title(f"{j}")
    plt.show()

# %%
df_new=df.copy()
df_new.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...         2    999         0  nonexistent
# 1  telephone   may         fri  ...         4    999         0  nonexistent
# 2  telephone   jun         wed  ...         1    999         0  nonexistent
# 3  telephone   jun         fri  ...         3    999         0  nonexistent
# 4   cellular   nov         mon  ...         1    999         0  nonexistent
#
# ...

# %%
df_new.describe()
# Out:
#                age     duration     campaign        pdays     previous  \
# count  4119.000000  4119.000000  4119.000000  4119.000000  4119.000000
# mean     40.113620   256.788055     2.537266   960.422190     0.190337
# std      10.313362   254.703736     2.568159   191.922786     0.541788
# min      18.000000     0.000000     1.000000     0.000000     0.000000
# 25%      32.000000   103.000000     1.000000   999.000000     0.000000
# 50%      38.000000   181.000000     2.000000   999.000000     0.000000
# 75%      47.000000   317.000000     3.000000   999.000000     0.000000
# max      88.000000  3643.000000    35.000000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m  nr.employed
# count   4119.000000     4119.000000    4119.000000  4119.000000  4119.000000
# mean       0.084972       93.579704     -40.499102     3.621356  5166.481695
# std        1.563114        0.579349       4.594578     1.733591    73.667904
# ...

# %%
nume_colms=df_new.select_dtypes(exclude='object').columns
nume_colms
# Out:
# Index(['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate',
#        'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed'],
#       dtype='object')

# %%
#outliner removal
for i in nume_colms:
    q1=np.percentile(df[i],25)
    q3=np.percentile(df[i],75)
    iqr=q3-q1
    lb=q1-1.5*iqr
    ub=q3+1.5*iqr
    cond1=df[i]<lb
    cond2=df[i]>ub
    outliers_Data=df[cond1|cond2]
    cond=cond1|cond2
    med=df[i].median()
    df_new[i]=np.where(cond,med,df[i])

# %%
df_new
# Out:
#        age          job  marital          education default  housing     loan  \
# 0     30.0  blue-collar  married           basic.9y      no      yes       no
# 1     39.0     services   single        high.school      no       no       no
# 2     25.0     services  married        high.school      no      yes       no
# 3     38.0     services  married           basic.9y      no  unknown  unknown
# 4     47.0       admin.  married  university.degree      no      yes       no
# ...    ...          ...      ...                ...     ...      ...      ...
# 4114  30.0       admin.  married           basic.6y      no      yes      yes
# 4115  39.0       admin.  married        high.school      no      yes       no
# 4116  27.0      student   single        high.school      no       no       no
# 4117  58.0       admin.  married        high.school      no       no       no
# 4118  34.0   management   single        high.school      no      yes       no
#
# ...

# %%
df_new.describe()
# Out:
#                age     duration     campaign   pdays  previous  emp.var.rate  \
# count  4119.000000  4119.000000  4119.000000  4119.0    4119.0   4119.000000
# mean     39.746540   201.982763     2.045885   999.0       0.0      0.084972
# std       9.660751   135.155498     1.239852     0.0       0.0      1.563114
# min      18.000000     0.000000     1.000000   999.0       0.0     -3.400000
# 25%      32.000000   103.000000     1.000000   999.0       0.0     -1.800000
# 50%      38.000000   181.000000     2.000000   999.0       0.0      1.100000
# 75%      47.000000   262.000000     3.000000   999.0       0.0      1.400000
# max      69.000000   638.000000     6.000000   999.0       0.0      1.400000
#
#        cons.price.idx  cons.conf.idx    euribor3m  nr.employed
# count     4119.000000    4119.000000  4119.000000  4119.000000
# mean        93.579704     -40.654649     3.621356  5166.481695
# std          0.579349       4.378644     1.733591    73.667904
# ...

# %%
for i in nume_colms:
    bef=round(df[i].skew(),2)
    aft=round(df_new[i].skew(),2)
    print(i,'before skew ',bef,'after skew ', aft)
# Out:
# age before skew  0.72 after skew  0.44
# duration before skew  3.29 after skew  1.1
# campaign before skew  4.0 after skew  1.33
# pdays before skew  -4.78 after skew  0.0
# previous before skew  4.02 after skew  0.0
# emp.var.rate before skew  -0.73 after skew  -0.73
# cons.price.idx before skew  -0.22 after skew  -0.22
# cons.conf.idx before skew  0.29 after skew  0.13
# euribor3m before skew  -0.72 after skew  -0.72
# nr.employed before skew  -1.08 after skew  -1.08

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.boxplot(df_new['age'],orient='h')
plt.subplot(1,2,2)
sns.boxplot(df['age'],orient='h')
# Out:
# <Axes: xlabel='age'>

# %%
plt.figure(figsize=(14,4))
plt.subplot(1,2,1)
sns.boxplot(df_new['emp.var.rate'],orient='h')
plt.title("after outliers removed")
plt.subplot(1,2,2)
sns.boxplot(df['emp.var.rate'],orient='h')
plt.show()

# %%
plt.figure(figsize=(14,4))
plt.subplot(1,2,1)
sns.boxplot(df_new['euribor3m'],orient='h')
plt.title("after outliers removed")
plt.subplot(1,2,2)
sns.boxplot(df['euribor3m'],orient='h')
plt.show()

# %%
plt.figure(figsize=(14,4))
plt.subplot(1,2,1)
sns.boxplot(df_new['nr.employed'],orient='h')
plt.subplot(1,2,2)
sns.boxplot(df['nr.employed'],orient='h')
plt.show()

# %%
plt.figure(figsize=(14,4))
plt.subplot(1,2,1)
plt.hist(df_new['campaign'],bins=30)
plt.title("after outliers removed")
plt.subplot(1,2,2)
plt.hist(df['campaign'],bins=30)
plt.show()

# %% [markdown]
# **SQRT Transformation Method**

# %%
for i in nume_colms:
    df_new[i]=np.sqrt(df_new[i])

# %% [markdown]
# **Reciprocal Transformation Method**

# %%
for i in nume_colms:
    df_new[i]=1/df_new[i]

# %%
plt.boxplot(df_new['campaign'],vert=False)
plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
for i,j in enumerate(nume_colms,1):
    plt.figure(figsize=(20,10))
    plt.subplot(5,2,i)
    sns.distplot(df_new[j])
    plt.title(j)
    plt.tight_layout() 
    plt.show()

# %%
from sklearn.preprocessing import PowerTransformer
pwr_tr=PowerTransformer(method='yeo-johnson')

# %%
for i ,j in enumerate(nume_colms,1):
    plt.subplot(4,3,i)
    plt.figure(figsize=(15,4))

 # Use 'yeo-johnson' method if the column contains non-positive values
    method = "box-cox" if (df[j] > 0).all() else "yeo-johnson"
    pe = PowerTransformer(method=method,standardize=True)
    df_new[j] = pe.fit_transform(df_new[[j]])
#     df_new[j] = yeo_tranform
    sns.histplot(yeo_tranform)
    plt.xlabel(f'Transformed {j.capitalize()}')
    plt.ylabel('Frequency')
    plt.title(j)
    plt.show()

# %%
sns.boxplot(df_new['duration'],orient='h')

# %% [markdown]
# **log transformation Method**

# %%
for i in nume_colms:
    df_new[i]=np.log(df_new[i])

# %%
plt.hist(df_new['campaign'],bins=20,label='Box cox')
plt.legend()

# %%
plt.hist(df_new['duration'],bins=30,label='Box cox')
plt.legend()

# %%
plt.hist(df['duration'],bins=30,label='Box cox')
plt.show()

# %%
for i in nume_colms:
    print(f"{df_new[i]} is {round(df_new[i].skew(),2)}")

# %%
plt.hist(df_new['previous'],bins=30,label='yeo johnson')
plt.show()

# %%
df_new.corr(numeric_only=True)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
categ_col=df_new.select_dtypes(include='object').columns
categ_col

# %%
for i in categ_col:
    df_new[i]=le.fit_transform(df_new[[i]])
    
df_new.head()

# %%
from sklearn.preprocessing import MinMaxScaler
ms=MinMaxScaler()

# %%
for i in df_new.columns:
    df_new[i]=ms.fit_transform(df_new[[i]])

# %%
df_new.head()
